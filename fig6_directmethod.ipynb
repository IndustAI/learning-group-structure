# %% [markdown]
# # Testing Predictive Performance of a direct prediction model on Flatland
#
# This notebook tests the predictive performance of a model trained to directly predict the next observation given the action and the current observation. Test results for several seeds are saved and can be plotted and compared against other methods using the fig6_createplot notebook. The network is the same as that used by our method, but the training protocol here uses batches of transitions collected from the environment.

# %%
import os
import gym
import math
import numpy as np
import time
from PIL import Image
import matplotlib.pyplot as plt
from IPython import display
import torch
import random
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import pickle

os.chdir('src/flatland/flat_game/')
from env import Env
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Loading chipmunk for Linux (64bit) [/home/william/.local/lib/python3.6/site-packages/pymunk/libchipmunk.so]

# %% [markdown]
# # Flatworld environment
#
# We start by defining the flatworld environment, which is based on the code available at https://github.com/Caselles/NeurIPS19-SBDRL. This environment returns pixel observations of a ball on a cyclical 2D grid. The available (discrete) actions step the ball by a fixed amount in all four directions.

# %%
RADIUS = 15
PERIOD = 5

class FlatWorld():
    
    class action_space():
        def __init__(self,n_actions):
            self.n = n_actions
            
        def sample(self, k=1):
            return torch.randint(0,self.n,(k,))       

    class observation_space():
        def __init__(self):
            self.shape = [84,84]
    
    def __init__(self, env_parameters, period=10, radius=15):

        self.action_space = self.action_space(4)
        self.observation_space = self.observation_space()  
        self.period = period
        
        self.step_size = 0.1*(63-2*env_parameters['agent']['radius'])/period
        start_positions_list = [27 + 10*self.step_size*i for i in range(period)]
        self.start_positions = []
        for i in start_positions_list:
            for j in start_positions_list:
                self.start_positions.append((i,j))
                        
        env_parameters['agent']['radius'] = radius
        self.env = Env(**env_parameters)
        
    def reset(self, start_position=None):
        if start_position==None:
            #obs = self.env.reset(position=random.sample(self.start_positions, 1)[0])
            obs = self.env.reset(position=self.start_positions[12])
        else:
             obs = self.env.reset(position=start_position)
        return torch.FloatTensor(obs)/255
    
    def step(self, action):
        action_dict = self.create_action_dict(action)
        obs, reward, done, info = self.env.step(action_dict)
        return torch.FloatTensor(obs)/255
    
    def create_action_dict(self, action):
        action_dict = {}
        if action == 0:
            action_dict['longitudinal_velocity'] = 0
            action_dict['lateral_velocity'] = self.step_size
            action_dict['angular_velocity'] = 0
        if action == 1:
            action_dict['longitudinal_velocity'] = 0
            action_dict['lateral_velocity'] = -self.step_size
            action_dict['angular_velocity'] = 0
        if action == 2:
            action_dict['longitudinal_velocity'] = self.step_size
            action_dict['lateral_velocity'] = 0
            action_dict['angular_velocity'] = 0
        if action == 3:
            action_dict['longitudinal_velocity'] = -self.step_size
            action_dict['lateral_velocity'] = 0
            action_dict['angular_velocity'] = 0
        return action_dict

# %% [markdown]
# ### Flatland hyperparameters

# %%
agent_parameters = {
    'radius': 15,
    'speed': 10,
    'rotation_speed' : math.pi/8,
    'living_penalty': 0,
    'position': (30,30),
    'angle': 0,
    'sensors': [
      
        {
           'nameSensor' : 'proximity_test',
           'typeSensor': 'proximity',
           'fovResolution': 64,
           'fovRange': 300,
           'fovAngle': math.pi ,
           'bodyAnchor': 'body',
           'd_r': 0,
           'd_theta': 0,
           'd_relativeOrientation': 0,
           'display': False,
        }
        
       
    ],
    'actions': ['forward', 'turn_left', 'turn_right', 'left', 'right', 'backward'],
    'measurements': ['health', 'poisons', 'fruits'],
    'texture': {
        'type': 'color',
        'c': (255, 255, 255)
    },
    'normalize_measurements': False,
    'normalize_states': False,
    'normalize_rewards': False
}

env_parameters = {
    'map':False,
    'n_rooms': 2,
    'display': False,
    'horizon': 10001,
    'shape': (84, 84),
    'mode': 'time',
    'poisons': {
        'number': 0,
        'positions': 'random',
        'size': 10,
        'reward': -10,
        'respawn': True,
        'texture': {
            'type': 'color',
            'c': (255, 255, 255),
        }
    },
    'fruits': {
        'number': 0,
        'positions': 'random',
        'size': 10,
        'reward': 10,
        'respawn': True,
        'texture': {
            'type': 'color',
            'c': (255, 150, 0),
        }
    },
    'obstacles': [
       
    ],
    'walls_texture': {
        'type': 'color',
        'c': (1, 1, 1)
    },
    'agent': agent_parameters
}

# %% [markdown]
# ### Define Encoder and Decoder (we use a compact latent space for the observations to which we concatenate a one-hot embedding of the actions)

# %%
class Encoder(nn.Module):

    def __init__(self, n_out=4, n_hid = 64):

        super().__init__()

        self.conv = nn.Conv2d(1, 5, 10, stride=3)
        self.fc1 = nn.Linear(180, n_hid)
        self.fc2 = nn.Linear(n_hid, n_out)

    def forward(self, x):
        if len(x.shape) != 3:
            x = x.unsqueeze(0)
        x = F.relu(self.conv(x.unsqueeze(1)))
        x = F.max_pool2d(x, 4, 4)
        x = x.view(-1, 180)
        x = F.relu(self.fc1(x))
        return self.fc2(x).squeeze()

class Decoder(nn.Module):
    
    def __init__(self, n_in=4, n_actions=4, n_hid = 64):

        super().__init__()
        
        self.fc1 = nn.Linear(n_in+n_actions, n_hid)
        self.fc2 = nn.Linear(n_hid, 180)
        self.conv = nn.ConvTranspose2d(5, 1, 34, stride=10)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = x.reshape(-1,5,6,6)
        x = self.conv(x)
        return torch.sigmoid(x).squeeze()

# %% [markdown]
# # Create dataset of transitions
#
# These transitions are collected from length 10 episodes, where each episode starts at the centre of the environment.

# %%
def create_dataset(n_data=5000):
    dataset = []
    obs_env = FlatWorld(env_parameters, period=PERIOD, radius=RADIUS)
    step = 0
    for i in range(n_data):
        if step == 0:
            obs_x = obs_env.reset()
        action = obs_env.action_space.sample().item()
        action_embedding = torch.zeros(4)
        action_embedding[action] = 1
        next_obs_x = obs_env.step(action)
        transition = (obs_x,action_embedding,next_obs_x)
        dataset.append(transition)
        obs_x = next_obs_x
        step += 1
        if step == 10:
            step = 0
    return dataset

# %%
dataset = create_dataset()

# %% [markdown]
# # Define a RepresentationLearner that puts all these elements together
#
# The RepresentationLearner, once initialized, can automatically be trained and tested on Flatland

# %%
def mk_dir(export_dir, quite=False):
    if not os.path.exists(export_dir):
        try:
            os.makedirs(export_dir)
            if not quite:
                print('Created directory: ', export_dir)
        except OSError as exc: # Guard against race condition
             if exc.errno != exc.errno.EEXIST:
                raise
        except Exception:
            pass
    else:
        if not quite:
            print('Directory already exists: ', export_dir)

class RepresentationLearner:
    def __init__(self,
                 dim=4,
                 n_hid=64,
                 lr_dec=1e-2,
                 lr_enc=1e-2,
                 exp_name=None):
        
        self.n_hid = n_hid
        self.lr_dec = lr_dec
        self.lr_enc = lr_enc
        self.exp_name = exp_name
        
        mk_dir('results',quite=True)
        self.save_folder = 'results/direct_' + self.exp_name
        mk_dir(self.save_folder, quite=True)
        
        self.decoder = Decoder(n_in = dim, n_hid = 64)
        self.encoder = Encoder(n_out = dim, n_hid = 64)
        self.optimizer_dec = optim.Adam(self.decoder.parameters(),
                                   lr=1e-3,
                                   weight_decay=0)

        self.optimizer_enc = optim.Adam(self.encoder.parameters(),
                                   lr=1e-3,
                                   weight_decay=0)
        
        self.losses = []
        
    def learn(self, n_sgd_steps=5000, batch_size=32):
        """
        Learns to directly predict the next observation from the current observation 
        and the chosen action
        n_sgd_steps: number of gradient descent steps
        batch_size: number of transitions in batch
        """

        t_start = time.time()
        self.losses = []
        for i in range(n_sgd_steps):
            batch = random.sample(dataset, batch_size)
            states = torch.stack([x[0] for x in batch])
            actions = torch.stack([x[1] for x in batch])
            next_states = torch.stack([x[2] for x in batch])

            embedding = torch.cat((self.encoder(states),actions),axis=1)
            reconstructions = self.decoder(embedding)

            loss = F.binary_cross_entropy(reconstructions, next_states)
            self.losses.append(loss.item())

            self.optimizer_dec.zero_grad()
            self.optimizer_enc.zero_grad()
            loss.backward()
            self.optimizer_enc.step()
            self.optimizer_dec.step()

            if i%10==0:
                print("iter {} : loss={:.3f} : last 10 iters in {:.3f}s".format(i, loss.item(), time.time() - t_start),
                      end="\r" if i%100 else "\n")
                t_start = time.time()
                
        plt.plot(self.losses)
        plt.savefig(self.save_folder + '/losses.png', bbox_inches='tight')
        plt.close()

    def test(self, rollout_len=500, rollouts=50, save_scores=True):
        """
        Measures reconstruction error as a function of rollout lengths over long rollouts
        rollout_len: length of rollout
        rollouts: number of rollouts over which to measure average reconstruction error
        """
        
        all_errors = []

        with torch.no_grad():
            for rollout in range(rollouts):
                obs_env = FlatWorld(env_parameters, period=PERIOD, radius=RADIUS)
                obs_x = obs_env.reset()
                reconstructed = obs_x
                errors = []
                for i in range(rollout_len):
                    action = obs_env.action_space.sample().item()
                    action_embedding = torch.zeros(4)
                    action_embedding[action] = 1
                    embedding = torch.cat((self.encoder(reconstructed),action_embedding))
                    reconstructed = self.decoder(embedding)
                    obs_x = obs_env.step(action)
                    errors.append(F.binary_cross_entropy(reconstructed, obs_x).detach())

                errors = torch.stack(errors)
                all_errors.append(errors)

            all_errors = torch.stack(all_errors)
            all_errors = all_errors.mean(axis=0)

        if save_scores:
            save_path = self.save_folder + '/scores.pkl'
        with open(save_path, 'wb+') as output:
            pickle.dump(all_errors, output, pickle.HIGHEST_PROTOCOL)
        plt.plot(all_errors)
        plt.savefig(self.save_folder + '/scores.png', bbox_inches='tight')
        plt.close()
        print("Results saved.")

        return all_errors

# %% [markdown]
# ### Train RepresentationLearner

# %%
seeds = 20
errors = []
for seed in range(seeds):
    agent = RepresentationLearner(exp_name=str(seed))
    agent.learn(n_sgd_steps=5000)
    error = agent.test()
    errors.append(error)
errors = torch.stack(errors)
errors = errors.mean(axis=0)
# Out:
# iter 0 : loss=0.689 : last 10 iters in 0.045s
# iter 100 : loss=0.180 : last 10 iters in 0.440s
# iter 200 : loss=0.142 : last 10 iters in 0.314s
# iter 300 : loss=0.127 : last 10 iters in 0.316s
# iter 400 : loss=0.124 : last 10 iters in 0.299s
# iter 500 : loss=0.117 : last 10 iters in 0.407s
# iter 600 : loss=0.149 : last 10 iters in 0.409s
# iter 700 : loss=0.096 : last 10 iters in 0.359s
# iter 800 : loss=0.099 : last 10 iters in 0.324s
# iter 900 : loss=0.065 : last 10 iters in 0.359s
# iter 1000 : loss=0.086 : last 10 iters in 0.354s
# iter 1100 : loss=0.058 : last 10 iters in 0.351s
# iter 1200 : loss=0.069 : last 10 iters in 0.338s
# iter 1300 : loss=0.066 : last 10 iters in 0.352s
# iter 1400 : loss=0.049 : last 10 iters in 0.330s
# iter 1500 : loss=0.045 : last 10 iters in 0.351s
# iter 1600 : loss=0.047 : last 10 iters in 0.412s
# iter 1700 : loss=0.036 : last 10 iters in 0.352s
# iter 1800 : loss=0.033 : last 10 iters in 0.371s
# iter 1900 : loss=0.030 : last 10 iters in 0.361s
# iter 2000 : loss=0.032 : last 10 iters in 0.351s
# iter 2100 : loss=0.034 : last 10 iters in 0.357s
# iter 2200 : loss=0.027 : last 10 iters in 0.359s
# iter 2300 : loss=0.029 : last 10 iters in 0.317s
# iter 2400 : loss=0.029 : last 10 iters in 0.317s
# iter 2500 : loss=0.029 : last 10 iters in 0.355s
# iter 2600 : loss=0.026 : last 10 iters in 0.352s
# iter 2700 : loss=0.025 : last 10 iters in 0.353s
# iter 2800 : loss=0.026 : last 10 iters in 0.366s
# iter 2900 : loss=0.025 : last 10 iters in 0.347s
# iter 3000 : loss=0.026 : last 10 iters in 0.299s
# iter 3100 : loss=0.022 : last 10 iters in 0.338s
# iter 3200 : loss=0.025 : last 10 iters in 0.300s
# iter 3300 : loss=0.025 : last 10 iters in 0.360s
# iter 3400 : loss=0.027 : last 10 iters in 0.377s
# iter 3500 : loss=0.026 : last 10 iters in 0.325s
# iter 3600 : loss=0.024 : last 10 iters in 0.339s
# iter 3700 : loss=0.025 : last 10 iters in 0.431s
# iter 3800 : loss=0.025 : last 10 iters in 0.500s
# iter 3900 : loss=0.023 : last 10 iters in 0.389s
# iter 4000 : loss=0.024 : last 10 iters in 0.372s
# iter 4100 : loss=0.021 : last 10 iters in 0.362s
# iter 4200 : loss=0.024 : last 10 iters in 0.336s
# iter 4300 : loss=0.025 : last 10 iters in 0.341s
# iter 4400 : loss=0.023 : last 10 iters in 0.360s
# iter 4500 : loss=0.022 : last 10 iters in 0.435s
# iter 4600 : loss=0.022 : last 10 iters in 0.369s
# iter 4700 : loss=0.023 : last 10 iters in 0.377s
# iter 4800 : loss=0.023 : last 10 iters in 0.539s
# iter 4900 : loss=0.022 : last 10 iters in 0.373s
# Results saved.ss=0.022 : last 10 iters in 0.315s
# iter 0 : loss=0.695 : last 10 iters in 0.040s
# iter 100 : loss=0.164 : last 10 iters in 0.340s
# iter 200 : loss=0.176 : last 10 iters in 0.702s
# iter 300 : loss=0.141 : last 10 iters in 0.428s
# iter 400 : loss=0.126 : last 10 iters in 0.388s
# iter 500 : loss=0.118 : last 10 iters in 0.406s
# iter 600 : loss=0.124 : last 10 iters in 0.315s
# iter 700 : loss=0.090 : last 10 iters in 0.415s
# iter 800 : loss=0.113 : last 10 iters in 0.580s
# iter 900 : loss=0.070 : last 10 iters in 0.365s
# iter 1000 : loss=0.081 : last 10 iters in 0.519s
# iter 1100 : loss=0.054 : last 10 iters in 0.430s
# iter 1200 : loss=0.046 : last 10 iters in 0.674s
# iter 1300 : loss=0.056 : last 10 iters in 0.332s
# iter 1400 : loss=0.052 : last 10 iters in 0.463s
# iter 1500 : loss=0.046 : last 10 iters in 0.330s
# iter 1600 : loss=0.041 : last 10 iters in 0.301s
# iter 1700 : loss=0.047 : last 10 iters in 0.630s
# iter 1800 : loss=0.034 : last 10 iters in 0.452s
# iter 1900 : loss=0.037 : last 10 iters in 0.388s
# iter 2000 : loss=0.029 : last 10 iters in 0.380s
# iter 2100 : loss=0.033 : last 10 iters in 0.376s
# iter 2200 : loss=0.031 : last 10 iters in 0.358s
# iter 2300 : loss=0.031 : last 10 iters in 0.345s
# iter 2400 : loss=0.033 : last 10 iters in 0.364s
# iter 2500 : loss=0.029 : last 10 iters in 0.305s
# iter 2600 : loss=0.028 : last 10 iters in 0.355s
# iter 2700 : loss=0.025 : last 10 iters in 0.353s
# iter 2800 : loss=0.027 : last 10 iters in 0.362s
# iter 2900 : loss=0.026 : last 10 iters in 0.361s
# iter 3000 : loss=0.026 : last 10 iters in 0.347s
# iter 3100 : loss=0.022 : last 10 iters in 0.381s
# iter 3200 : loss=0.028 : last 10 iters in 0.342s
# iter 3300 : loss=0.023 : last 10 iters in 0.353s
# iter 3400 : loss=0.024 : last 10 iters in 0.332s
# iter 3500 : loss=0.024 : last 10 iters in 0.346s
# iter 3600 : loss=0.022 : last 10 iters in 0.325s
# iter 3700 : loss=0.025 : last 10 iters in 0.321s
# iter 3800 : loss=0.024 : last 10 iters in 0.361s
# iter 3900 : loss=0.023 : last 10 iters in 0.383s
# iter 4000 : loss=0.023 : last 10 iters in 0.581s
# iter 4100 : loss=0.023 : last 10 iters in 0.333s
# iter 4200 : loss=0.024 : last 10 iters in 0.304s
# iter 4300 : loss=0.023 : last 10 iters in 0.454s
# iter 4400 : loss=0.022 : last 10 iters in 0.361s
# iter 4500 : loss=0.021 : last 10 iters in 0.360s
# iter 4600 : loss=0.023 : last 10 iters in 0.344s
# iter 4700 : loss=0.021 : last 10 iters in 0.356s
# iter 4800 : loss=0.024 : last 10 iters in 0.363s
# iter 4900 : loss=0.022 : last 10 iters in 0.368s
# iter 4990 : loss=0.023 : last 10 iters in 0.370s
# /home/william/Bureau/Python/gantime/rep-learning/paris/src/flatland/flat_game/sensors/proximity_sensor.py:42: RuntimeWarning: invalid value encountered in not_equal
#   mask = resized_img != 0
# Results saved.
# iter 0 : loss=0.701 : last 10 iters in 0.033s
# iter 100 : loss=0.183 : last 10 iters in 0.402s
# iter 200 : loss=0.153 : last 10 iters in 0.477s
# iter 300 : loss=0.162 : last 10 iters in 0.422s
# iter 400 : loss=0.124 : last 10 iters in 0.344s
# iter 500 : loss=0.130 : last 10 iters in 0.286s
# iter 600 : loss=0.110 : last 10 iters in 0.453s
# iter 700 : loss=0.115 : last 10 iters in 0.407s
# iter 800 : loss=0.100 : last 10 iters in 0.331s
# iter 900 : loss=0.089 : last 10 iters in 0.303s
# iter 1000 : loss=0.106 : last 10 iters in 0.403s
# iter 1100 : loss=0.084 : last 10 iters in 0.489s
# iter 1200 : loss=0.065 : last 10 iters in 0.358s
# iter 1300 : loss=0.071 : last 10 iters in 0.317s
# iter 1400 : loss=0.046 : last 10 iters in 0.349s
# iter 1500 : loss=0.056 : last 10 iters in 0.298s
# iter 1600 : loss=0.056 : last 10 iters in 0.406s
# iter 1700 : loss=0.064 : last 10 iters in 0.370s
# iter 1800 : loss=0.043 : last 10 iters in 0.469s
# iter 1900 : loss=0.042 : last 10 iters in 0.380s
# iter 2000 : loss=0.038 : last 10 iters in 0.359s
# iter 2100 : loss=0.033 : last 10 iters in 0.327s
# iter 2200 : loss=0.037 : last 10 iters in 0.371s
# iter 2300 : loss=0.030 : last 10 iters in 0.435s
# iter 2400 : loss=0.029 : last 10 iters in 0.356s
# iter 2500 : loss=0.033 : last 10 iters in 0.296s
# iter 2600 : loss=0.029 : last 10 iters in 0.331s
# iter 2700 : loss=0.038 : last 10 iters in 0.308s
# iter 2800 : loss=0.028 : last 10 iters in 0.443s
# iter 2900 : loss=0.029 : last 10 iters in 0.336s
# iter 3000 : loss=0.027 : last 10 iters in 0.343s
# iter 3100 : loss=0.030 : last 10 iters in 0.322s
# iter 3200 : loss=0.026 : last 10 iters in 0.316s
# iter 3300 : loss=0.029 : last 10 iters in 0.320s
# iter 3400 : loss=0.025 : last 10 iters in 0.314s
# iter 3500 : loss=0.024 : last 10 iters in 0.335s
# iter 3600 : loss=0.027 : last 10 iters in 0.409s
# iter 3700 : loss=0.030 : last 10 iters in 0.674s
# iter 3800 : loss=0.027 : last 10 iters in 0.559s
# iter 3900 : loss=0.023 : last 10 iters in 0.327s
# iter 4000 : loss=0.025 : last 10 iters in 0.297s
# iter 4100 : loss=0.023 : last 10 iters in 0.328s
# iter 4200 : loss=0.024 : last 10 iters in 0.334s
# iter 4300 : loss=0.023 : last 10 iters in 0.317s
# iter 4400 : loss=0.025 : last 10 iters in 0.332s
# iter 4500 : loss=0.023 : last 10 iters in 0.349s
# iter 4600 : loss=0.024 : last 10 iters in 0.315s
# iter 4700 : loss=0.025 : last 10 iters in 0.321s
# iter 4800 : loss=0.025 : last 10 iters in 0.364s
# iter 4900 : loss=0.023 : last 10 iters in 0.355s
# Results saved.ss=0.024 : last 10 iters in 0.347s
# iter 0 : loss=0.686 : last 10 iters in 0.029s
# iter 100 : loss=0.176 : last 10 iters in 0.386s
# iter 200 : loss=0.160 : last 10 iters in 0.277s
# iter 300 : loss=0.133 : last 10 iters in 0.338s
# iter 400 : loss=0.113 : last 10 iters in 0.393s
# iter 500 : loss=0.116 : last 10 iters in 0.333s
# iter 600 : loss=0.111 : last 10 iters in 0.434s
# iter 700 : loss=0.088 : last 10 iters in 0.512s
# iter 800 : loss=0.102 : last 10 iters in 0.324s
# iter 900 : loss=0.092 : last 10 iters in 0.297s
# iter 1000 : loss=0.114 : last 10 iters in 0.362s
# iter 1100 : loss=0.069 : last 10 iters in 0.328s
# iter 1200 : loss=0.069 : last 10 iters in 0.350s
# iter 1300 : loss=0.059 : last 10 iters in 0.350s
# iter 1400 : loss=0.049 : last 10 iters in 0.389s
# iter 1500 : loss=0.046 : last 10 iters in 0.323s
# iter 1600 : loss=0.045 : last 10 iters in 0.308s
# iter 1700 : loss=0.035 : last 10 iters in 0.351s
# iter 1800 : loss=0.044 : last 10 iters in 0.399s
# iter 1900 : loss=0.035 : last 10 iters in 0.401s
# iter 2000 : loss=0.034 : last 10 iters in 0.417s
# iter 2100 : loss=0.031 : last 10 iters in 0.446s
# iter 2200 : loss=0.028 : last 10 iters in 0.353s
# iter 2300 : loss=0.031 : last 10 iters in 0.325s
# iter 2400 : loss=0.029 : last 10 iters in 0.338s
# iter 2500 : loss=0.026 : last 10 iters in 0.376s
# iter 2600 : loss=0.029 : last 10 iters in 0.296s
# iter 2700 : loss=0.029 : last 10 iters in 0.358s
# iter 2800 : loss=0.025 : last 10 iters in 0.296s
# iter 2900 : loss=0.026 : last 10 iters in 0.361s
# iter 3000 : loss=0.024 : last 10 iters in 0.347s
# iter 3100 : loss=0.026 : last 10 iters in 0.408s
# iter 3200 : loss=0.026 : last 10 iters in 0.359s
# iter 3300 : loss=0.024 : last 10 iters in 0.359s
# iter 3400 : loss=0.024 : last 10 iters in 0.351s
# iter 3500 : loss=0.024 : last 10 iters in 0.353s
# iter 3600 : loss=0.026 : last 10 iters in 0.359s
# iter 3700 : loss=0.024 : last 10 iters in 0.333s
# iter 3800 : loss=0.023 : last 10 iters in 0.390s
# iter 3900 : loss=0.024 : last 10 iters in 0.356s
# iter 4000 : loss=0.022 : last 10 iters in 0.390s
# iter 4100 : loss=0.023 : last 10 iters in 0.323s
# iter 4200 : loss=0.022 : last 10 iters in 0.345s
# iter 4300 : loss=0.022 : last 10 iters in 0.333s
# iter 4400 : loss=0.022 : last 10 iters in 0.316s
# iter 4500 : loss=0.022 : last 10 iters in 0.337s
# iter 4600 : loss=0.021 : last 10 iters in 0.302s
# iter 4700 : loss=0.023 : last 10 iters in 0.345s
# iter 4800 : loss=0.023 : last 10 iters in 0.347s
# iter 4900 : loss=0.023 : last 10 iters in 0.342s
# Results saved.ss=0.022 : last 10 iters in 0.323s
# iter 0 : loss=0.690 : last 10 iters in 0.044s
# iter 100 : loss=0.190 : last 10 iters in 0.385s
# iter 200 : loss=0.165 : last 10 iters in 0.325s
# iter 300 : loss=0.157 : last 10 iters in 0.338s
# iter 400 : loss=0.122 : last 10 iters in 0.326s
# iter 500 : loss=0.130 : last 10 iters in 0.446s
# iter 600 : loss=0.104 : last 10 iters in 0.387s
# iter 700 : loss=0.083 : last 10 iters in 0.370s
# iter 800 : loss=0.098 : last 10 iters in 0.437s
# iter 900 : loss=0.081 : last 10 iters in 0.451s
# iter 1000 : loss=0.082 : last 10 iters in 0.504s
# iter 1100 : loss=0.090 : last 10 iters in 0.282s
# iter 1200 : loss=0.076 : last 10 iters in 0.507s
# iter 1300 : loss=0.053 : last 10 iters in 0.342s
# iter 1400 : loss=0.065 : last 10 iters in 0.325s
# iter 1500 : loss=0.049 : last 10 iters in 0.326s
# iter 1600 : loss=0.057 : last 10 iters in 0.360s
# iter 1700 : loss=0.041 : last 10 iters in 0.330s
# iter 1800 : loss=0.034 : last 10 iters in 0.498s
# iter 1900 : loss=0.035 : last 10 iters in 0.395s
# iter 2000 : loss=0.036 : last 10 iters in 0.329s
# iter 2100 : loss=0.034 : last 10 iters in 0.318s
# iter 2200 : loss=0.031 : last 10 iters in 0.415s
# iter 2300 : loss=0.030 : last 10 iters in 0.353s
# iter 2400 : loss=0.027 : last 10 iters in 0.318s
# iter 2500 : loss=0.031 : last 10 iters in 0.327s
# iter 2600 : loss=0.028 : last 10 iters in 0.404s
# iter 2700 : loss=0.027 : last 10 iters in 0.321s
# iter 2800 : loss=0.025 : last 10 iters in 0.364s
# iter 2900 : loss=0.025 : last 10 iters in 0.499s
# iter 3000 : loss=0.023 : last 10 iters in 0.488s
# iter 3100 : loss=0.024 : last 10 iters in 0.453s
# iter 3200 : loss=0.025 : last 10 iters in 0.350s
# iter 3300 : loss=0.025 : last 10 iters in 0.324s
# iter 3400 : loss=0.024 : last 10 iters in 0.489s
# iter 3500 : loss=0.023 : last 10 iters in 0.369s
# iter 3600 : loss=0.023 : last 10 iters in 0.498s
# iter 3700 : loss=0.025 : last 10 iters in 0.417s
# iter 3800 : loss=0.023 : last 10 iters in 0.362s
# iter 3900 : loss=0.027 : last 10 iters in 0.370s
# iter 4000 : loss=0.022 : last 10 iters in 0.336s
# iter 4100 : loss=0.022 : last 10 iters in 0.386s
# iter 4200 : loss=0.025 : last 10 iters in 0.364s
# iter 4300 : loss=0.023 : last 10 iters in 0.361s
# iter 4400 : loss=0.023 : last 10 iters in 0.498s
# iter 4500 : loss=0.025 : last 10 iters in 0.351s
# iter 4600 : loss=0.024 : last 10 iters in 0.381s
# iter 4700 : loss=0.022 : last 10 iters in 0.305s
# iter 4800 : loss=0.023 : last 10 iters in 0.330s
# iter 4900 : loss=0.023 : last 10 iters in 0.339s
# Results saved.ss=0.022 : last 10 iters in 0.382s
# iter 0 : loss=0.700 : last 10 iters in 0.054s
# iter 100 : loss=0.202 : last 10 iters in 0.334s
# iter 200 : loss=0.166 : last 10 iters in 0.314s
# iter 300 : loss=0.149 : last 10 iters in 0.326s
# iter 400 : loss=0.126 : last 10 iters in 0.320s
# iter 500 : loss=0.125 : last 10 iters in 0.304s
# iter 600 : loss=0.123 : last 10 iters in 0.372s
# iter 700 : loss=0.091 : last 10 iters in 0.331s
# iter 800 : loss=0.092 : last 10 iters in 0.352s
# iter 900 : loss=0.070 : last 10 iters in 0.332s
# iter 1000 : loss=0.065 : last 10 iters in 0.326s
# iter 1100 : loss=0.065 : last 10 iters in 0.298s
# iter 1200 : loss=0.073 : last 10 iters in 0.319s
# iter 1300 : loss=0.053 : last 10 iters in 0.327s
# iter 1400 : loss=0.038 : last 10 iters in 0.309s
# iter 1500 : loss=0.045 : last 10 iters in 0.325s
# iter 1600 : loss=0.056 : last 10 iters in 0.336s
# iter 1700 : loss=0.038 : last 10 iters in 0.325s
# iter 1800 : loss=0.041 : last 10 iters in 0.426s
# iter 1900 : loss=0.032 : last 10 iters in 0.318s
# iter 2000 : loss=0.030 : last 10 iters in 0.329s
# iter 2100 : loss=0.036 : last 10 iters in 0.315s
# iter 2200 : loss=0.030 : last 10 iters in 0.326s
# iter 2300 : loss=0.028 : last 10 iters in 0.352s
# iter 2400 : loss=0.026 : last 10 iters in 0.323s
# iter 2500 : loss=0.031 : last 10 iters in 0.319s
# iter 2600 : loss=0.025 : last 10 iters in 0.326s
# iter 2700 : loss=0.028 : last 10 iters in 0.326s
# iter 2800 : loss=0.025 : last 10 iters in 0.321s
# iter 2900 : loss=0.025 : last 10 iters in 0.405s
# iter 3000 : loss=0.023 : last 10 iters in 0.328s
# iter 3100 : loss=0.026 : last 10 iters in 0.366s
# iter 3200 : loss=0.025 : last 10 iters in 0.362s
# iter 3300 : loss=0.023 : last 10 iters in 0.360s
# iter 3400 : loss=0.025 : last 10 iters in 0.368s
# iter 3500 : loss=0.026 : last 10 iters in 0.377s
# iter 3600 : loss=0.023 : last 10 iters in 0.394s
# iter 3700 : loss=0.024 : last 10 iters in 0.453s
# iter 3800 : loss=0.023 : last 10 iters in 0.349s
# iter 3900 : loss=0.025 : last 10 iters in 0.428s
# iter 4000 : loss=0.023 : last 10 iters in 0.354s
# iter 4100 : loss=0.024 : last 10 iters in 0.489s
# iter 4200 : loss=0.022 : last 10 iters in 0.430s
# iter 4300 : loss=0.022 : last 10 iters in 0.368s
# iter 4400 : loss=0.023 : last 10 iters in 0.438s
# iter 4500 : loss=0.024 : last 10 iters in 0.375s
# iter 4600 : loss=0.024 : last 10 iters in 0.335s
# iter 4700 : loss=0.022 : last 10 iters in 0.375s
# iter 4800 : loss=0.023 : last 10 iters in 0.394s
# iter 4900 : loss=0.022 : last 10 iters in 0.384s
# Results saved.ss=0.023 : last 10 iters in 0.391s
# iter 0 : loss=0.690 : last 10 iters in 0.030s
# iter 100 : loss=0.210 : last 10 iters in 0.359s
# iter 200 : loss=0.166 : last 10 iters in 0.514s
# iter 300 : loss=0.154 : last 10 iters in 0.710s
# iter 400 : loss=0.123 : last 10 iters in 0.357s
# iter 500 : loss=0.119 : last 10 iters in 0.353s
# iter 600 : loss=0.129 : last 10 iters in 0.430s
# iter 700 : loss=0.111 : last 10 iters in 0.426s
# iter 800 : loss=0.091 : last 10 iters in 0.370s
# iter 900 : loss=0.075 : last 10 iters in 0.491s
# iter 1000 : loss=0.094 : last 10 iters in 0.360s
# iter 1100 : loss=0.087 : last 10 iters in 0.360s
# iter 1200 : loss=0.070 : last 10 iters in 0.336s
# iter 1300 : loss=0.052 : last 10 iters in 0.389s
# iter 1400 : loss=0.058 : last 10 iters in 0.408s
# iter 1500 : loss=0.068 : last 10 iters in 0.410s
# iter 1600 : loss=0.044 : last 10 iters in 0.354s
# iter 1700 : loss=0.046 : last 10 iters in 0.427s
# iter 1800 : loss=0.039 : last 10 iters in 0.374s
# iter 1900 : loss=0.038 : last 10 iters in 0.359s
# iter 2000 : loss=0.035 : last 10 iters in 0.312s
# iter 2100 : loss=0.035 : last 10 iters in 0.459s
# iter 2200 : loss=0.028 : last 10 iters in 0.311s
# iter 2300 : loss=0.031 : last 10 iters in 0.329s
# iter 2400 : loss=0.033 : last 10 iters in 0.428s
# iter 2500 : loss=0.030 : last 10 iters in 0.377s
# iter 2600 : loss=0.028 : last 10 iters in 0.358s
# iter 2700 : loss=0.028 : last 10 iters in 0.365s
# iter 2800 : loss=0.027 : last 10 iters in 0.601s
# iter 2900 : loss=0.028 : last 10 iters in 0.352s
# iter 3000 : loss=0.028 : last 10 iters in 0.357s
# iter 3100 : loss=0.027 : last 10 iters in 0.372s
# iter 3200 : loss=0.027 : last 10 iters in 0.331s
# iter 3300 : loss=0.027 : last 10 iters in 0.537s
# iter 3400 : loss=0.027 : last 10 iters in 0.324s
# iter 3500 : loss=0.027 : last 10 iters in 0.325s
# iter 3600 : loss=0.027 : last 10 iters in 0.301s
# iter 3700 : loss=0.025 : last 10 iters in 0.380s
# iter 3800 : loss=0.024 : last 10 iters in 0.359s
# iter 3900 : loss=0.025 : last 10 iters in 0.394s
# iter 4000 : loss=0.027 : last 10 iters in 0.317s
# iter 4100 : loss=0.025 : last 10 iters in 0.309s
# iter 4200 : loss=0.023 : last 10 iters in 0.331s
# iter 4300 : loss=0.023 : last 10 iters in 0.398s
# iter 4400 : loss=0.024 : last 10 iters in 0.331s
# iter 4500 : loss=0.024 : last 10 iters in 0.286s
# iter 4600 : loss=0.024 : last 10 iters in 0.359s
# iter 4700 : loss=0.025 : last 10 iters in 0.366s
# iter 4800 : loss=0.024 : last 10 iters in 0.373s
# iter 4900 : loss=0.025 : last 10 iters in 0.386s
# Results saved.ss=0.023 : last 10 iters in 0.312s
# iter 0 : loss=0.703 : last 10 iters in 0.031s
# iter 100 : loss=0.177 : last 10 iters in 0.322s
# iter 200 : loss=0.165 : last 10 iters in 0.323s
# iter 300 : loss=0.166 : last 10 iters in 0.321s
# iter 400 : loss=0.131 : last 10 iters in 0.325s
# iter 500 : loss=0.133 : last 10 iters in 0.321s
# iter 600 : loss=0.106 : last 10 iters in 0.422s
# iter 700 : loss=0.120 : last 10 iters in 0.391s
# iter 800 : loss=0.097 : last 10 iters in 0.365s
# iter 900 : loss=0.074 : last 10 iters in 0.354s
# iter 1000 : loss=0.065 : last 10 iters in 0.360s
# iter 1100 : loss=0.065 : last 10 iters in 0.400s
# iter 1200 : loss=0.054 : last 10 iters in 0.378s
# iter 1300 : loss=0.052 : last 10 iters in 0.360s
# iter 1400 : loss=0.042 : last 10 iters in 0.390s
# iter 1500 : loss=0.043 : last 10 iters in 0.345s
# iter 1600 : loss=0.042 : last 10 iters in 0.364s
# iter 1700 : loss=0.043 : last 10 iters in 0.524s
# iter 1800 : loss=0.032 : last 10 iters in 0.363s
# iter 1900 : loss=0.034 : last 10 iters in 0.393s
# iter 2000 : loss=0.030 : last 10 iters in 0.352s
# iter 2100 : loss=0.034 : last 10 iters in 0.362s
# iter 2200 : loss=0.028 : last 10 iters in 0.323s
# iter 2300 : loss=0.030 : last 10 iters in 0.324s
# iter 2400 : loss=0.030 : last 10 iters in 0.317s
# iter 2500 : loss=0.026 : last 10 iters in 0.322s
# iter 2600 : loss=0.025 : last 10 iters in 0.320s
# iter 2700 : loss=0.026 : last 10 iters in 0.320s
# iter 2800 : loss=0.026 : last 10 iters in 0.317s
# iter 2900 : loss=0.027 : last 10 iters in 0.319s
# iter 3000 : loss=0.024 : last 10 iters in 0.326s
# iter 3100 : loss=0.025 : last 10 iters in 0.319s
# iter 3200 : loss=0.025 : last 10 iters in 0.324s
# iter 3300 : loss=0.024 : last 10 iters in 0.321s
# iter 3400 : loss=0.026 : last 10 iters in 0.322s
# iter 3500 : loss=0.025 : last 10 iters in 0.325s
# iter 3600 : loss=0.025 : last 10 iters in 0.315s
# iter 3700 : loss=0.026 : last 10 iters in 0.324s
# iter 3800 : loss=0.023 : last 10 iters in 0.276s
# iter 3900 : loss=0.023 : last 10 iters in 0.293s
# iter 4000 : loss=0.023 : last 10 iters in 0.323s
# iter 4100 : loss=0.022 : last 10 iters in 0.326s
# iter 4200 : loss=0.024 : last 10 iters in 0.389s
# iter 4300 : loss=0.022 : last 10 iters in 0.394s
# iter 4400 : loss=0.023 : last 10 iters in 0.355s
# iter 4500 : loss=0.022 : last 10 iters in 0.367s
# iter 4600 : loss=0.021 : last 10 iters in 0.341s
# iter 4700 : loss=0.022 : last 10 iters in 0.386s
# iter 4800 : loss=0.021 : last 10 iters in 0.344s
# iter 4900 : loss=0.021 : last 10 iters in 0.378s
# Results saved.ss=0.022 : last 10 iters in 0.369s
# iter 0 : loss=0.702 : last 10 iters in 0.031s
# iter 100 : loss=0.182 : last 10 iters in 0.324s
# iter 200 : loss=0.157 : last 10 iters in 0.331s
# iter 300 : loss=0.140 : last 10 iters in 0.297s
# iter 400 : loss=0.119 : last 10 iters in 0.310s
# iter 500 : loss=0.133 : last 10 iters in 0.291s
# iter 600 : loss=0.119 : last 10 iters in 0.302s
# iter 700 : loss=0.109 : last 10 iters in 0.352s
# iter 800 : loss=0.099 : last 10 iters in 0.324s
# iter 900 : loss=0.109 : last 10 iters in 0.288s
# iter 1000 : loss=0.077 : last 10 iters in 0.324s
# iter 1100 : loss=0.055 : last 10 iters in 0.323s
# iter 1200 : loss=0.058 : last 10 iters in 0.324s
# iter 1300 : loss=0.055 : last 10 iters in 0.322s
# iter 1400 : loss=0.045 : last 10 iters in 0.321s
# iter 1500 : loss=0.043 : last 10 iters in 0.322s
# iter 1600 : loss=0.044 : last 10 iters in 0.320s
# iter 1700 : loss=0.038 : last 10 iters in 0.316s
# iter 1800 : loss=0.042 : last 10 iters in 0.273s
# iter 1900 : loss=0.031 : last 10 iters in 0.268s
# iter 2000 : loss=0.039 : last 10 iters in 0.320s
# iter 2100 : loss=0.031 : last 10 iters in 0.316s
# iter 2200 : loss=0.027 : last 10 iters in 0.319s
# iter 2300 : loss=0.034 : last 10 iters in 0.272s
# iter 2400 : loss=0.032 : last 10 iters in 0.321s
# iter 2500 : loss=0.030 : last 10 iters in 0.291s
# iter 2600 : loss=0.031 : last 10 iters in 0.325s
# iter 2700 : loss=0.027 : last 10 iters in 0.291s
# iter 2800 : loss=0.025 : last 10 iters in 0.269s
# iter 2900 : loss=0.026 : last 10 iters in 0.295s
# iter 3000 : loss=0.026 : last 10 iters in 0.371s
# iter 3100 : loss=0.027 : last 10 iters in 0.299s
# iter 3200 : loss=0.026 : last 10 iters in 0.275s
# iter 3300 : loss=0.025 : last 10 iters in 0.322s
# iter 3400 : loss=0.024 : last 10 iters in 0.320s
# iter 3500 : loss=0.027 : last 10 iters in 0.285s
# iter 3600 : loss=0.026 : last 10 iters in 0.323s
# iter 3700 : loss=0.025 : last 10 iters in 0.277s
# iter 3800 : loss=0.024 : last 10 iters in 0.285s
# iter 3900 : loss=0.024 : last 10 iters in 0.326s
# iter 4000 : loss=0.025 : last 10 iters in 0.327s
# iter 4100 : loss=0.026 : last 10 iters in 0.320s
# iter 4200 : loss=0.024 : last 10 iters in 0.330s
# iter 4300 : loss=0.024 : last 10 iters in 0.275s
# iter 4400 : loss=0.026 : last 10 iters in 0.334s
# iter 4500 : loss=0.024 : last 10 iters in 0.282s
# iter 4600 : loss=0.024 : last 10 iters in 0.332s
# iter 4700 : loss=0.024 : last 10 iters in 0.333s
# iter 4800 : loss=0.022 : last 10 iters in 0.315s
# iter 4900 : loss=0.024 : last 10 iters in 0.320s
# Results saved.ss=0.022 : last 10 iters in 0.337s
# iter 0 : loss=0.694 : last 10 iters in 0.031s
# iter 100 : loss=0.180 : last 10 iters in 0.283s
# iter 200 : loss=0.178 : last 10 iters in 0.287s
# iter 300 : loss=0.133 : last 10 iters in 0.330s
# iter 400 : loss=0.139 : last 10 iters in 0.271s
# iter 500 : loss=0.127 : last 10 iters in 0.322s
# iter 600 : loss=0.103 : last 10 iters in 0.325s
# iter 700 : loss=0.123 : last 10 iters in 0.275s
# iter 800 : loss=0.094 : last 10 iters in 0.416s
# iter 900 : loss=0.096 : last 10 iters in 0.276s
# iter 1000 : loss=0.095 : last 10 iters in 0.330s
# iter 1100 : loss=0.066 : last 10 iters in 0.285s
# iter 1200 : loss=0.078 : last 10 iters in 0.297s
# iter 1300 : loss=0.061 : last 10 iters in 0.320s
# iter 1400 : loss=0.060 : last 10 iters in 0.324s
# iter 1500 : loss=0.058 : last 10 iters in 0.301s
# iter 1600 : loss=0.047 : last 10 iters in 0.319s
# iter 1700 : loss=0.042 : last 10 iters in 0.301s
# iter 1800 : loss=0.052 : last 10 iters in 0.269s
# iter 1900 : loss=0.036 : last 10 iters in 0.317s
# iter 2000 : loss=0.036 : last 10 iters in 0.285s
# iter 2100 : loss=0.037 : last 10 iters in 0.318s
# iter 2200 : loss=0.029 : last 10 iters in 0.320s
# iter 2300 : loss=0.033 : last 10 iters in 0.320s
# iter 2400 : loss=0.032 : last 10 iters in 0.350s
# iter 2500 : loss=0.032 : last 10 iters in 0.337s
# iter 2600 : loss=0.028 : last 10 iters in 0.316s
# iter 2700 : loss=0.027 : last 10 iters in 0.267s
# iter 2800 : loss=0.029 : last 10 iters in 0.266s
# iter 2900 : loss=0.031 : last 10 iters in 0.319s
# iter 3000 : loss=0.026 : last 10 iters in 0.266s
# iter 3100 : loss=0.027 : last 10 iters in 0.266s
# iter 3200 : loss=0.027 : last 10 iters in 0.316s
# iter 3300 : loss=0.026 : last 10 iters in 0.272s
# iter 3400 : loss=0.025 : last 10 iters in 0.275s
# iter 3500 : loss=0.024 : last 10 iters in 0.270s
# iter 3600 : loss=0.025 : last 10 iters in 0.270s
# iter 3700 : loss=0.024 : last 10 iters in 0.279s
# iter 3800 : loss=0.024 : last 10 iters in 0.331s
# iter 3900 : loss=0.023 : last 10 iters in 0.272s
# iter 4000 : loss=0.024 : last 10 iters in 0.324s
# iter 4100 : loss=0.024 : last 10 iters in 0.326s
# iter 4200 : loss=0.024 : last 10 iters in 0.318s
# iter 4300 : loss=0.022 : last 10 iters in 0.325s
# iter 4400 : loss=0.023 : last 10 iters in 0.331s
# iter 4500 : loss=0.023 : last 10 iters in 0.326s
# iter 4600 : loss=0.023 : last 10 iters in 0.277s
# iter 4700 : loss=0.022 : last 10 iters in 0.338s
# iter 4800 : loss=0.022 : last 10 iters in 0.333s
# iter 4900 : loss=0.023 : last 10 iters in 0.334s
# Results saved.ss=0.024 : last 10 iters in 0.284s
# iter 0 : loss=0.694 : last 10 iters in 0.031s
# iter 100 : loss=0.183 : last 10 iters in 0.382s
# iter 200 : loss=0.168 : last 10 iters in 0.386s
# iter 300 : loss=0.148 : last 10 iters in 0.384s
# iter 400 : loss=0.139 : last 10 iters in 0.382s
# iter 500 : loss=0.112 : last 10 iters in 0.383s
# iter 600 : loss=0.115 : last 10 iters in 0.367s
# iter 700 : loss=0.112 : last 10 iters in 0.354s
# iter 800 : loss=0.118 : last 10 iters in 0.381s
# iter 900 : loss=0.086 : last 10 iters in 0.340s
# iter 1000 : loss=0.074 : last 10 iters in 0.358s
# iter 1100 : loss=0.083 : last 10 iters in 0.356s
# iter 1200 : loss=0.091 : last 10 iters in 0.356s
# iter 1300 : loss=0.049 : last 10 iters in 0.378s
# iter 1400 : loss=0.063 : last 10 iters in 0.361s
# iter 1500 : loss=0.041 : last 10 iters in 0.373s
# iter 1600 : loss=0.057 : last 10 iters in 0.337s
# iter 1700 : loss=0.043 : last 10 iters in 0.334s
# iter 1800 : loss=0.040 : last 10 iters in 0.368s
# iter 1900 : loss=0.032 : last 10 iters in 0.329s
# iter 2000 : loss=0.043 : last 10 iters in 0.298s
# iter 2100 : loss=0.029 : last 10 iters in 0.336s
# iter 2200 : loss=0.039 : last 10 iters in 0.326s
# iter 2300 : loss=0.028 : last 10 iters in 0.277s
# iter 2400 : loss=0.028 : last 10 iters in 0.450s
# iter 2500 : loss=0.029 : last 10 iters in 0.331s
# iter 2600 : loss=0.026 : last 10 iters in 0.340s
# iter 2700 : loss=0.024 : last 10 iters in 0.361s
# iter 2800 : loss=0.027 : last 10 iters in 0.337s
# iter 2900 : loss=0.025 : last 10 iters in 0.352s
# iter 3000 : loss=0.027 : last 10 iters in 0.321s
# iter 3100 : loss=0.024 : last 10 iters in 0.334s
# iter 3200 : loss=0.026 : last 10 iters in 0.330s
# iter 3300 : loss=0.026 : last 10 iters in 0.357s
# iter 3400 : loss=0.026 : last 10 iters in 0.355s
# iter 3500 : loss=0.025 : last 10 iters in 0.296s
# iter 3600 : loss=0.026 : last 10 iters in 0.327s
# iter 3700 : loss=0.025 : last 10 iters in 0.298s
# iter 3800 : loss=0.023 : last 10 iters in 0.297s
# iter 3900 : loss=0.023 : last 10 iters in 0.324s
# iter 4000 : loss=0.021 : last 10 iters in 0.298s
# iter 4100 : loss=0.024 : last 10 iters in 0.328s
# iter 4200 : loss=0.025 : last 10 iters in 0.349s
# iter 4300 : loss=0.025 : last 10 iters in 0.333s
# iter 4400 : loss=0.023 : last 10 iters in 0.337s
# iter 4500 : loss=0.025 : last 10 iters in 0.325s
# iter 4600 : loss=0.024 : last 10 iters in 0.346s
# iter 4700 : loss=0.022 : last 10 iters in 0.331s
# iter 4800 : loss=0.023 : last 10 iters in 0.318s
# iter 4900 : loss=0.024 : last 10 iters in 0.331s
# Results saved.ss=0.022 : last 10 iters in 0.343s
# iter 0 : loss=0.697 : last 10 iters in 0.030s
# iter 100 : loss=0.207 : last 10 iters in 0.327s
# iter 200 : loss=0.165 : last 10 iters in 0.351s
# iter 300 : loss=0.140 : last 10 iters in 0.346s
# iter 400 : loss=0.137 : last 10 iters in 0.347s
# iter 500 : loss=0.130 : last 10 iters in 0.334s
# iter 600 : loss=0.109 : last 10 iters in 0.368s
# iter 700 : loss=0.102 : last 10 iters in 0.373s
# iter 800 : loss=0.105 : last 10 iters in 0.362s
# iter 900 : loss=0.102 : last 10 iters in 0.372s
# iter 1000 : loss=0.070 : last 10 iters in 0.355s
# iter 1100 : loss=0.083 : last 10 iters in 0.353s
# iter 1200 : loss=0.075 : last 10 iters in 0.341s
# iter 1300 : loss=0.052 : last 10 iters in 0.375s
# iter 1400 : loss=0.045 : last 10 iters in 0.367s
# iter 1500 : loss=0.039 : last 10 iters in 0.299s
# iter 1600 : loss=0.054 : last 10 iters in 0.391s
# iter 1700 : loss=0.035 : last 10 iters in 0.401s
# iter 1800 : loss=0.037 : last 10 iters in 0.360s
# iter 1900 : loss=0.037 : last 10 iters in 0.360s
# iter 2000 : loss=0.033 : last 10 iters in 0.329s
# iter 2100 : loss=0.032 : last 10 iters in 0.414s
# iter 2200 : loss=0.032 : last 10 iters in 0.349s
# iter 2300 : loss=0.030 : last 10 iters in 0.354s
# iter 2400 : loss=0.032 : last 10 iters in 0.548s
# iter 2500 : loss=0.030 : last 10 iters in 0.445s
# iter 2600 : loss=0.028 : last 10 iters in 0.444s
# iter 2700 : loss=0.027 : last 10 iters in 0.377s
# iter 2800 : loss=0.027 : last 10 iters in 0.370s
# iter 2900 : loss=0.026 : last 10 iters in 0.320s
# iter 3000 : loss=0.028 : last 10 iters in 0.325s
# iter 3100 : loss=0.027 : last 10 iters in 0.439s
# iter 3200 : loss=0.024 : last 10 iters in 0.433s
# iter 3300 : loss=0.024 : last 10 iters in 0.543s
# iter 3400 : loss=0.024 : last 10 iters in 0.421s
# iter 3500 : loss=0.025 : last 10 iters in 0.324s
# iter 3600 : loss=0.025 : last 10 iters in 0.369s
# iter 3700 : loss=0.025 : last 10 iters in 0.678s
# iter 3800 : loss=0.025 : last 10 iters in 0.728s
# iter 3900 : loss=0.025 : last 10 iters in 0.563s
# iter 4000 : loss=0.024 : last 10 iters in 0.352s
# iter 4100 : loss=0.024 : last 10 iters in 0.302s
# iter 4200 : loss=0.023 : last 10 iters in 0.289s
# iter 4300 : loss=0.023 : last 10 iters in 0.333s
# iter 4400 : loss=0.022 : last 10 iters in 0.344s
# iter 4500 : loss=0.023 : last 10 iters in 0.371s
# iter 4600 : loss=0.022 : last 10 iters in 0.710s
# iter 4700 : loss=0.022 : last 10 iters in 0.573s
# iter 4800 : loss=0.023 : last 10 iters in 0.630s
# iter 4900 : loss=0.025 : last 10 iters in 0.734s
# Results saved.ss=0.023 : last 10 iters in 0.579s
# iter 0 : loss=0.683 : last 10 iters in 0.054s
# iter 100 : loss=0.199 : last 10 iters in 0.332s
# iter 200 : loss=0.166 : last 10 iters in 0.361s
# iter 300 : loss=0.137 : last 10 iters in 0.306s
# iter 400 : loss=0.150 : last 10 iters in 0.371s
# iter 500 : loss=0.130 : last 10 iters in 0.351s
# iter 600 : loss=0.105 : last 10 iters in 0.388s
# iter 700 : loss=0.104 : last 10 iters in 0.435s
# iter 800 : loss=0.099 : last 10 iters in 0.433s
# iter 900 : loss=0.096 : last 10 iters in 0.348s
# iter 1000 : loss=0.087 : last 10 iters in 0.350s
# iter 1100 : loss=0.079 : last 10 iters in 0.359s
# iter 1200 : loss=0.079 : last 10 iters in 0.360s
# iter 1300 : loss=0.055 : last 10 iters in 0.358s
# iter 1400 : loss=0.051 : last 10 iters in 0.358s
# iter 1500 : loss=0.057 : last 10 iters in 0.372s
# iter 1600 : loss=0.043 : last 10 iters in 0.317s
# iter 1700 : loss=0.050 : last 10 iters in 0.343s
# iter 1800 : loss=0.048 : last 10 iters in 0.328s
# iter 1900 : loss=0.035 : last 10 iters in 0.331s
# iter 2000 : loss=0.035 : last 10 iters in 0.357s
# iter 2100 : loss=0.033 : last 10 iters in 0.319s
# iter 2200 : loss=0.033 : last 10 iters in 0.300s
# iter 2300 : loss=0.030 : last 10 iters in 0.330s
# iter 2400 : loss=0.028 : last 10 iters in 0.310s
# iter 2500 : loss=0.028 : last 10 iters in 0.325s
# iter 2600 : loss=0.034 : last 10 iters in 0.332s
# iter 2700 : loss=0.026 : last 10 iters in 0.323s
# iter 2800 : loss=0.027 : last 10 iters in 0.297s
# iter 2900 : loss=0.025 : last 10 iters in 0.304s
# iter 3000 : loss=0.028 : last 10 iters in 0.307s
# iter 3100 : loss=0.025 : last 10 iters in 0.327s
# iter 3200 : loss=0.027 : last 10 iters in 0.324s
# iter 3300 : loss=0.027 : last 10 iters in 0.321s
# iter 3400 : loss=0.028 : last 10 iters in 0.397s
# iter 3500 : loss=0.024 : last 10 iters in 0.330s
# iter 3600 : loss=0.025 : last 10 iters in 0.337s
# iter 3700 : loss=0.023 : last 10 iters in 0.331s
# iter 3800 : loss=0.023 : last 10 iters in 0.423s
# iter 3900 : loss=0.024 : last 10 iters in 0.387s
# iter 4000 : loss=0.026 : last 10 iters in 0.337s
# iter 4100 : loss=0.024 : last 10 iters in 0.321s
# iter 4200 : loss=0.022 : last 10 iters in 0.322s
# iter 4300 : loss=0.024 : last 10 iters in 0.336s
# iter 4400 : loss=0.024 : last 10 iters in 0.322s
# iter 4500 : loss=0.023 : last 10 iters in 0.381s
# iter 4600 : loss=0.023 : last 10 iters in 0.325s
# iter 4700 : loss=0.021 : last 10 iters in 0.370s
# iter 4800 : loss=0.023 : last 10 iters in 0.364s
# iter 4900 : loss=0.022 : last 10 iters in 0.340s
# Results saved.ss=0.023 : last 10 iters in 0.347s
# iter 0 : loss=0.686 : last 10 iters in 0.031s
# iter 100 : loss=0.167 : last 10 iters in 0.325s
# iter 200 : loss=0.165 : last 10 iters in 0.326s
# iter 300 : loss=0.152 : last 10 iters in 0.331s
# iter 400 : loss=0.136 : last 10 iters in 0.338s
# iter 500 : loss=0.117 : last 10 iters in 0.331s
# iter 600 : loss=0.143 : last 10 iters in 0.394s
# iter 700 : loss=0.094 : last 10 iters in 0.351s
# iter 800 : loss=0.064 : last 10 iters in 0.305s
# iter 900 : loss=0.100 : last 10 iters in 0.357s
# iter 1000 : loss=0.117 : last 10 iters in 0.296s
# iter 1100 : loss=0.068 : last 10 iters in 0.349s
# iter 1200 : loss=0.066 : last 10 iters in 0.357s
# iter 1300 : loss=0.045 : last 10 iters in 0.348s
# iter 1400 : loss=0.040 : last 10 iters in 0.363s
# iter 1500 : loss=0.042 : last 10 iters in 0.354s
# iter 1600 : loss=0.046 : last 10 iters in 0.359s
# iter 1700 : loss=0.043 : last 10 iters in 0.350s
# iter 1800 : loss=0.041 : last 10 iters in 0.352s
# iter 1900 : loss=0.034 : last 10 iters in 0.352s
# iter 2000 : loss=0.037 : last 10 iters in 0.354s
# iter 2100 : loss=0.030 : last 10 iters in 0.296s
# iter 2200 : loss=0.036 : last 10 iters in 0.350s
# iter 2300 : loss=0.031 : last 10 iters in 0.350s
# iter 2400 : loss=0.027 : last 10 iters in 0.467s
# iter 2500 : loss=0.031 : last 10 iters in 0.354s
# iter 2600 : loss=0.029 : last 10 iters in 0.349s
# iter 2700 : loss=0.026 : last 10 iters in 0.353s
# iter 2800 : loss=0.028 : last 10 iters in 0.297s
# iter 2900 : loss=0.025 : last 10 iters in 0.296s
# iter 3000 : loss=0.026 : last 10 iters in 0.355s
# iter 3100 : loss=0.026 : last 10 iters in 0.349s
# iter 3200 : loss=0.027 : last 10 iters in 0.359s
# iter 3300 : loss=0.026 : last 10 iters in 0.298s
# iter 3400 : loss=0.026 : last 10 iters in 0.328s
# iter 3500 : loss=0.026 : last 10 iters in 0.351s
# iter 3600 : loss=0.025 : last 10 iters in 0.360s
# iter 3700 : loss=0.023 : last 10 iters in 0.352s
# iter 3800 : loss=0.024 : last 10 iters in 0.354s
# iter 3900 : loss=0.025 : last 10 iters in 0.361s
# iter 4000 : loss=0.024 : last 10 iters in 0.360s
# iter 4100 : loss=0.024 : last 10 iters in 0.355s
# iter 4200 : loss=0.025 : last 10 iters in 0.307s
# iter 4300 : loss=0.025 : last 10 iters in 0.355s
# iter 4400 : loss=0.023 : last 10 iters in 0.365s
# iter 4500 : loss=0.026 : last 10 iters in 0.305s
# iter 4600 : loss=0.022 : last 10 iters in 0.371s
# iter 4700 : loss=0.023 : last 10 iters in 0.361s
# iter 4800 : loss=0.022 : last 10 iters in 0.368s
# iter 4900 : loss=0.024 : last 10 iters in 0.366s
# Results saved.ss=0.022 : last 10 iters in 0.389s
# iter 0 : loss=0.687 : last 10 iters in 0.032s
# iter 100 : loss=0.177 : last 10 iters in 0.349s
# iter 200 : loss=0.164 : last 10 iters in 0.297s
# iter 300 : loss=0.142 : last 10 iters in 0.351s
# iter 400 : loss=0.153 : last 10 iters in 0.360s
# iter 500 : loss=0.118 : last 10 iters in 0.351s
# iter 600 : loss=0.113 : last 10 iters in 0.351s
# iter 700 : loss=0.097 : last 10 iters in 0.354s
# iter 800 : loss=0.102 : last 10 iters in 0.350s
# iter 900 : loss=0.086 : last 10 iters in 0.313s
# iter 1000 : loss=0.085 : last 10 iters in 0.296s
# iter 1100 : loss=0.069 : last 10 iters in 0.328s
# iter 1200 : loss=0.068 : last 10 iters in 0.354s
# iter 1300 : loss=0.070 : last 10 iters in 0.356s
# iter 1400 : loss=0.059 : last 10 iters in 0.352s
# iter 1500 : loss=0.046 : last 10 iters in 0.353s
# iter 1600 : loss=0.040 : last 10 iters in 0.355s
# iter 1700 : loss=0.048 : last 10 iters in 0.305s
# iter 1800 : loss=0.039 : last 10 iters in 0.347s
# iter 1900 : loss=0.035 : last 10 iters in 0.352s
# iter 2000 : loss=0.031 : last 10 iters in 0.337s
# iter 2100 : loss=0.033 : last 10 iters in 0.356s
# iter 2200 : loss=0.033 : last 10 iters in 0.348s
# iter 2300 : loss=0.029 : last 10 iters in 0.336s
# iter 2400 : loss=0.030 : last 10 iters in 0.352s
# iter 2500 : loss=0.028 : last 10 iters in 0.436s
# iter 2600 : loss=0.029 : last 10 iters in 0.303s
# iter 2700 : loss=0.028 : last 10 iters in 0.358s
# iter 2800 : loss=0.027 : last 10 iters in 0.352s
# iter 2900 : loss=0.025 : last 10 iters in 0.362s
# iter 3000 : loss=0.025 : last 10 iters in 0.360s
# iter 3100 : loss=0.026 : last 10 iters in 0.361s
# iter 3200 : loss=0.023 : last 10 iters in 0.375s
# iter 3300 : loss=0.024 : last 10 iters in 0.304s
# iter 3400 : loss=0.025 : last 10 iters in 0.369s
# iter 3500 : loss=0.025 : last 10 iters in 0.361s
# iter 3600 : loss=0.026 : last 10 iters in 0.349s
# iter 3700 : loss=0.025 : last 10 iters in 0.369s
# iter 3800 : loss=0.024 : last 10 iters in 0.361s
# iter 3900 : loss=0.023 : last 10 iters in 0.364s
# iter 4000 : loss=0.024 : last 10 iters in 0.329s
# iter 4100 : loss=0.023 : last 10 iters in 0.361s
# iter 4200 : loss=0.023 : last 10 iters in 0.368s
# iter 4300 : loss=0.024 : last 10 iters in 0.370s
# iter 4400 : loss=0.022 : last 10 iters in 0.375s
# iter 4500 : loss=0.024 : last 10 iters in 0.364s
# iter 4600 : loss=0.024 : last 10 iters in 0.373s
# iter 4700 : loss=0.023 : last 10 iters in 0.362s
# iter 4800 : loss=0.022 : last 10 iters in 0.383s
# iter 4900 : loss=0.023 : last 10 iters in 0.371s
# Results saved.ss=0.023 : last 10 iters in 0.378s
# iter 0 : loss=0.696 : last 10 iters in 0.033s
# iter 100 : loss=0.182 : last 10 iters in 0.360s
# iter 200 : loss=0.167 : last 10 iters in 0.296s
# iter 300 : loss=0.146 : last 10 iters in 0.350s
# iter 400 : loss=0.138 : last 10 iters in 0.351s
# iter 500 : loss=0.120 : last 10 iters in 0.355s
# iter 600 : loss=0.122 : last 10 iters in 0.354s
# iter 700 : loss=0.106 : last 10 iters in 0.354s
# iter 800 : loss=0.082 : last 10 iters in 0.359s
# iter 900 : loss=0.089 : last 10 iters in 0.360s
# iter 1000 : loss=0.101 : last 10 iters in 0.351s
# iter 1100 : loss=0.089 : last 10 iters in 0.296s
# iter 1200 : loss=0.099 : last 10 iters in 0.356s
# iter 1300 : loss=0.090 : last 10 iters in 0.352s
# iter 1400 : loss=0.080 : last 10 iters in 0.353s
# iter 1500 : loss=0.072 : last 10 iters in 0.351s
# iter 1600 : loss=0.044 : last 10 iters in 0.354s
# iter 1700 : loss=0.044 : last 10 iters in 0.359s
# iter 1800 : loss=0.055 : last 10 iters in 0.352s
# iter 1900 : loss=0.039 : last 10 iters in 0.364s
# iter 2000 : loss=0.040 : last 10 iters in 0.361s
# iter 2100 : loss=0.038 : last 10 iters in 0.350s
# iter 2200 : loss=0.037 : last 10 iters in 0.398s
# iter 2300 : loss=0.035 : last 10 iters in 0.320s
# iter 2400 : loss=0.040 : last 10 iters in 0.300s
# iter 2500 : loss=0.030 : last 10 iters in 0.432s
# iter 2600 : loss=0.028 : last 10 iters in 0.296s
# iter 2700 : loss=0.033 : last 10 iters in 0.348s
# iter 2800 : loss=0.030 : last 10 iters in 0.348s
# iter 2900 : loss=0.025 : last 10 iters in 0.352s
# iter 3000 : loss=0.032 : last 10 iters in 0.312s
# iter 3100 : loss=0.027 : last 10 iters in 0.356s
# iter 3200 : loss=0.028 : last 10 iters in 0.370s
# iter 3300 : loss=0.024 : last 10 iters in 0.354s
# iter 3400 : loss=0.023 : last 10 iters in 0.340s
# iter 3500 : loss=0.025 : last 10 iters in 0.360s
# iter 3600 : loss=0.025 : last 10 iters in 0.324s
# iter 3700 : loss=0.024 : last 10 iters in 0.362s
# iter 3800 : loss=0.022 : last 10 iters in 0.302s
# iter 3900 : loss=0.023 : last 10 iters in 0.359s
# iter 4000 : loss=0.023 : last 10 iters in 0.316s
# iter 4100 : loss=0.024 : last 10 iters in 0.304s
# iter 4200 : loss=0.022 : last 10 iters in 0.365s
# iter 4300 : loss=0.023 : last 10 iters in 0.353s
# iter 4400 : loss=0.023 : last 10 iters in 0.365s
# iter 4500 : loss=0.023 : last 10 iters in 0.319s
# iter 4600 : loss=0.023 : last 10 iters in 0.310s
# iter 4700 : loss=0.024 : last 10 iters in 0.370s
# iter 4800 : loss=0.022 : last 10 iters in 0.312s
# iter 4900 : loss=0.022 : last 10 iters in 0.326s
# Results saved.ss=0.022 : last 10 iters in 0.315s
# iter 0 : loss=0.685 : last 10 iters in 0.031s
# iter 100 : loss=0.196 : last 10 iters in 0.352s
# iter 200 : loss=0.171 : last 10 iters in 0.356s
# iter 300 : loss=0.165 : last 10 iters in 0.321s
# iter 400 : loss=0.148 : last 10 iters in 0.296s
# iter 500 : loss=0.113 : last 10 iters in 0.350s
# iter 600 : loss=0.109 : last 10 iters in 0.297s
# iter 700 : loss=0.107 : last 10 iters in 0.368s
# iter 800 : loss=0.125 : last 10 iters in 0.296s
# iter 900 : loss=0.090 : last 10 iters in 0.342s
# iter 1000 : loss=0.085 : last 10 iters in 0.352s
# iter 1100 : loss=0.084 : last 10 iters in 0.326s
# iter 1200 : loss=0.066 : last 10 iters in 0.343s
# iter 1300 : loss=0.068 : last 10 iters in 0.325s
# iter 1400 : loss=0.056 : last 10 iters in 0.318s
# iter 1500 : loss=0.045 : last 10 iters in 0.356s
# iter 1600 : loss=0.043 : last 10 iters in 0.353s
# iter 1700 : loss=0.038 : last 10 iters in 0.355s
# iter 1800 : loss=0.035 : last 10 iters in 0.302s
# iter 1900 : loss=0.038 : last 10 iters in 0.345s
# iter 2000 : loss=0.045 : last 10 iters in 0.297s
# iter 2100 : loss=0.033 : last 10 iters in 0.299s
# iter 2200 : loss=0.037 : last 10 iters in 0.326s
# iter 2300 : loss=0.029 : last 10 iters in 0.348s
# iter 2400 : loss=0.031 : last 10 iters in 0.355s
# iter 2500 : loss=0.027 : last 10 iters in 0.353s
# iter 2600 : loss=0.025 : last 10 iters in 0.354s
# iter 2700 : loss=0.028 : last 10 iters in 0.350s
# iter 2800 : loss=0.027 : last 10 iters in 0.297s
# iter 2900 : loss=0.025 : last 10 iters in 0.357s
# iter 3000 : loss=0.025 : last 10 iters in 0.297s
# iter 3100 : loss=0.026 : last 10 iters in 0.348s
# iter 3200 : loss=0.024 : last 10 iters in 0.344s
# iter 3300 : loss=0.025 : last 10 iters in 0.359s
# iter 3400 : loss=0.022 : last 10 iters in 0.308s
# iter 3500 : loss=0.024 : last 10 iters in 0.355s
# iter 3600 : loss=0.025 : last 10 iters in 0.357s
# iter 3700 : loss=0.023 : last 10 iters in 0.361s
# iter 3800 : loss=0.024 : last 10 iters in 0.356s
# iter 3900 : loss=0.022 : last 10 iters in 0.361s
# iter 4000 : loss=0.023 : last 10 iters in 0.364s
# iter 4100 : loss=0.023 : last 10 iters in 0.312s
# iter 4200 : loss=0.022 : last 10 iters in 0.360s
# iter 4300 : loss=0.025 : last 10 iters in 0.367s
# iter 4400 : loss=0.022 : last 10 iters in 0.331s
# iter 4500 : loss=0.023 : last 10 iters in 0.322s
# iter 4600 : loss=0.023 : last 10 iters in 0.361s
# iter 4700 : loss=0.021 : last 10 iters in 0.306s
# iter 4800 : loss=0.023 : last 10 iters in 0.360s
# iter 4900 : loss=0.022 : last 10 iters in 0.313s
# Results saved.ss=0.024 : last 10 iters in 0.370s
# iter 0 : loss=0.682 : last 10 iters in 0.029s
# iter 100 : loss=0.196 : last 10 iters in 0.352s
# iter 200 : loss=0.161 : last 10 iters in 0.357s
# iter 300 : loss=0.164 : last 10 iters in 0.296s
# iter 400 : loss=0.140 : last 10 iters in 0.347s
# iter 500 : loss=0.114 : last 10 iters in 0.349s
# iter 600 : loss=0.108 : last 10 iters in 0.360s
# iter 700 : loss=0.129 : last 10 iters in 0.307s
# iter 800 : loss=0.092 : last 10 iters in 0.296s
# iter 900 : loss=0.077 : last 10 iters in 0.350s
# iter 1000 : loss=0.068 : last 10 iters in 0.359s
# iter 1100 : loss=0.081 : last 10 iters in 0.360s
# iter 1200 : loss=0.055 : last 10 iters in 0.328s
# iter 1300 : loss=0.046 : last 10 iters in 0.353s
# iter 1400 : loss=0.046 : last 10 iters in 0.344s
# iter 1500 : loss=0.045 : last 10 iters in 0.357s
# iter 1600 : loss=0.041 : last 10 iters in 0.359s
# iter 1700 : loss=0.038 : last 10 iters in 0.354s
# iter 1800 : loss=0.034 : last 10 iters in 0.351s
# iter 1900 : loss=0.030 : last 10 iters in 0.351s
# iter 2000 : loss=0.034 : last 10 iters in 0.353s
# iter 2100 : loss=0.031 : last 10 iters in 0.338s
# iter 2200 : loss=0.031 : last 10 iters in 0.348s
# iter 2300 : loss=0.030 : last 10 iters in 0.351s
# iter 2400 : loss=0.027 : last 10 iters in 0.351s
# iter 2500 : loss=0.027 : last 10 iters in 0.357s
# iter 2600 : loss=0.026 : last 10 iters in 0.342s
# iter 2700 : loss=0.026 : last 10 iters in 0.355s
# iter 2800 : loss=0.025 : last 10 iters in 0.360s
# iter 2900 : loss=0.026 : last 10 iters in 0.369s
# iter 3000 : loss=0.025 : last 10 iters in 0.359s
# iter 3100 : loss=0.025 : last 10 iters in 0.360s
# iter 3200 : loss=0.023 : last 10 iters in 0.361s
# iter 3300 : loss=0.023 : last 10 iters in 0.344s
# iter 3400 : loss=0.023 : last 10 iters in 0.369s
# iter 3500 : loss=0.027 : last 10 iters in 0.371s
# iter 3600 : loss=0.023 : last 10 iters in 0.375s
# iter 3700 : loss=0.023 : last 10 iters in 0.372s
# iter 3800 : loss=0.021 : last 10 iters in 0.372s
# iter 3900 : loss=0.024 : last 10 iters in 0.378s
# iter 4000 : loss=0.023 : last 10 iters in 0.391s
# iter 4100 : loss=0.022 : last 10 iters in 0.374s
# iter 4200 : loss=0.024 : last 10 iters in 0.390s
# iter 4300 : loss=0.023 : last 10 iters in 0.329s
# iter 4400 : loss=0.022 : last 10 iters in 0.358s
# iter 4500 : loss=0.024 : last 10 iters in 0.397s
# iter 4600 : loss=0.022 : last 10 iters in 0.397s
# iter 4700 : loss=0.022 : last 10 iters in 0.394s
# iter 4800 : loss=0.022 : last 10 iters in 0.385s
# iter 4900 : loss=0.023 : last 10 iters in 0.390s
# Results saved.ss=0.022 : last 10 iters in 0.401s
# iter 0 : loss=0.687 : last 10 iters in 0.033s
# iter 100 : loss=0.172 : last 10 iters in 0.304s
# iter 200 : loss=0.161 : last 10 iters in 0.350s
# iter 300 : loss=0.126 : last 10 iters in 0.343s
# iter 400 : loss=0.128 : last 10 iters in 0.359s
# iter 500 : loss=0.112 : last 10 iters in 0.333s
# iter 600 : loss=0.096 : last 10 iters in 0.354s
# iter 700 : loss=0.110 : last 10 iters in 0.359s
# iter 800 : loss=0.114 : last 10 iters in 0.359s
# iter 900 : loss=0.110 : last 10 iters in 0.355s
# iter 1000 : loss=0.082 : last 10 iters in 0.342s
# iter 1100 : loss=0.069 : last 10 iters in 0.296s
# iter 1200 : loss=0.068 : last 10 iters in 0.358s
# iter 1300 : loss=0.069 : last 10 iters in 0.350s
# iter 1400 : loss=0.053 : last 10 iters in 0.355s
# iter 1500 : loss=0.052 : last 10 iters in 0.352s
# iter 1600 : loss=0.040 : last 10 iters in 0.359s
# iter 1700 : loss=0.044 : last 10 iters in 0.348s
# iter 1800 : loss=0.034 : last 10 iters in 0.350s
# iter 1900 : loss=0.038 : last 10 iters in 0.333s
# iter 2000 : loss=0.033 : last 10 iters in 0.349s
# iter 2100 : loss=0.030 : last 10 iters in 0.351s
# iter 2200 : loss=0.030 : last 10 iters in 0.368s
# iter 2300 : loss=0.030 : last 10 iters in 0.360s
# iter 2400 : loss=0.029 : last 10 iters in 0.297s
# iter 2500 : loss=0.029 : last 10 iters in 0.348s
# iter 2600 : loss=0.030 : last 10 iters in 0.351s
# iter 2700 : loss=0.028 : last 10 iters in 0.348s
# iter 2800 : loss=0.027 : last 10 iters in 0.360s
# iter 2900 : loss=0.026 : last 10 iters in 0.359s
# iter 3000 : loss=0.027 : last 10 iters in 0.351s
# iter 3100 : loss=0.024 : last 10 iters in 0.337s
# iter 3200 : loss=0.026 : last 10 iters in 0.362s
# iter 3300 : loss=0.024 : last 10 iters in 0.311s
# iter 3400 : loss=0.025 : last 10 iters in 0.359s
# iter 3500 : loss=0.025 : last 10 iters in 0.360s
# iter 3600 : loss=0.025 : last 10 iters in 0.318s
# iter 3700 : loss=0.024 : last 10 iters in 0.364s
# iter 3800 : loss=0.024 : last 10 iters in 0.370s
# iter 3900 : loss=0.024 : last 10 iters in 0.309s
# iter 4000 : loss=0.023 : last 10 iters in 0.362s
# iter 4100 : loss=0.023 : last 10 iters in 0.360s
# iter 4200 : loss=0.023 : last 10 iters in 0.376s
# iter 4300 : loss=0.023 : last 10 iters in 0.379s
# iter 4400 : loss=0.023 : last 10 iters in 0.372s
# iter 4500 : loss=0.023 : last 10 iters in 0.334s
# iter 4600 : loss=0.023 : last 10 iters in 0.371s
# iter 4700 : loss=0.022 : last 10 iters in 0.323s
# iter 4800 : loss=0.022 : last 10 iters in 0.340s
# iter 4900 : loss=0.022 : last 10 iters in 0.387s
# Results saved.ss=0.022 : last 10 iters in 0.382s
# iter 0 : loss=0.686 : last 10 iters in 0.032s
# iter 100 : loss=0.173 : last 10 iters in 0.352s
# iter 200 : loss=0.158 : last 10 iters in 0.353s
# iter 300 : loss=0.145 : last 10 iters in 0.335s
# iter 400 : loss=0.125 : last 10 iters in 0.351s
# iter 500 : loss=0.132 : last 10 iters in 0.301s
# iter 600 : loss=0.108 : last 10 iters in 0.356s
# iter 700 : loss=0.079 : last 10 iters in 0.353s
# iter 800 : loss=0.091 : last 10 iters in 0.359s
# iter 900 : loss=0.090 : last 10 iters in 0.351s
# iter 1000 : loss=0.071 : last 10 iters in 0.296s
# iter 1100 : loss=0.082 : last 10 iters in 0.303s
# iter 1200 : loss=0.066 : last 10 iters in 0.361s
# iter 1300 : loss=0.048 : last 10 iters in 0.353s
# iter 1400 : loss=0.048 : last 10 iters in 0.350s
# iter 1500 : loss=0.043 : last 10 iters in 0.363s
# iter 1600 : loss=0.041 : last 10 iters in 0.356s
# iter 1700 : loss=0.055 : last 10 iters in 0.360s
# iter 1800 : loss=0.040 : last 10 iters in 0.365s
# iter 1900 : loss=0.033 : last 10 iters in 0.359s
# iter 2000 : loss=0.033 : last 10 iters in 0.353s
# iter 2100 : loss=0.035 : last 10 iters in 0.358s
# iter 2200 : loss=0.038 : last 10 iters in 0.351s
# iter 2300 : loss=0.035 : last 10 iters in 0.351s
# iter 2400 : loss=0.028 : last 10 iters in 0.348s
# iter 2500 : loss=0.026 : last 10 iters in 0.352s
# iter 2600 : loss=0.025 : last 10 iters in 0.349s
# iter 2700 : loss=0.026 : last 10 iters in 0.353s
# iter 2800 : loss=0.028 : last 10 iters in 0.330s
# iter 2900 : loss=0.030 : last 10 iters in 0.357s
# iter 3000 : loss=0.026 : last 10 iters in 0.355s
# iter 3100 : loss=0.025 : last 10 iters in 0.357s
# iter 3200 : loss=0.027 : last 10 iters in 0.351s
# iter 3300 : loss=0.028 : last 10 iters in 0.351s
# iter 3400 : loss=0.027 : last 10 iters in 0.312s
# iter 3500 : loss=0.025 : last 10 iters in 0.359s
# iter 3600 : loss=0.026 : last 10 iters in 0.304s
# iter 3700 : loss=0.026 : last 10 iters in 0.360s
# iter 3800 : loss=0.024 : last 10 iters in 0.361s
# iter 3900 : loss=0.026 : last 10 iters in 0.361s
# iter 4000 : loss=0.025 : last 10 iters in 0.358s
# iter 4100 : loss=0.024 : last 10 iters in 0.361s
# iter 4200 : loss=0.026 : last 10 iters in 0.356s
# iter 4300 : loss=0.027 : last 10 iters in 0.361s
# iter 4400 : loss=0.025 : last 10 iters in 0.369s
# iter 4500 : loss=0.022 : last 10 iters in 0.362s
# iter 4600 : loss=0.024 : last 10 iters in 0.360s
# iter 4700 : loss=0.026 : last 10 iters in 0.463s
# iter 4800 : loss=0.023 : last 10 iters in 0.671s
# iter 4900 : loss=0.022 : last 10 iters in 0.596s
# Results saved.ss=0.026 : last 10 iters in 0.736s
